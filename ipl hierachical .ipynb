# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
data = pd.read_csv("auction.csv")
data
# Out:
#       Unnamed: 0       Country                Player  \
# 0              0        Guyana  Christopher Barnwell
# 1              1  South Africa           Johan Botha
# 2              2     Australia      Daniel Christian
# 3              3     Australia        Michael Clarke
# 4              4     Australia   Nathan Coulter-Nile
# ...          ...           ...                   ...
# 1047        1047       England              Joe Root
# 1048        1048    Bangladesh       Shakib al Hasan
# 1049        1049         India          Abdul Basith
# 1050        1050       England              Joe Root
# 1051        1051    Bangladesh       Shakib al Hasan
#
#                              Team  Base price  Winning bid  Year
# 0     Royal Challengers Bangalore        30.5         30.5  2013
# 1                Delhi Daredevils       183.0        274.5  2013
# 2     Royal Challengers Bangalore        61.0         61.0  2013
# 3             Pune Warriors India       244.0        244.0  2013
# ...

# %%
print("Unique Base prices:", data['Base price'].unique())
print("Unique Winning bids:", data['Winning bid'].unique())
# Out:
# Unique Base prices: [ 30.5 183.   61.  244.   12.2 122.  200.  150.  100.   50.   30.   10.
#   20.   75.   40. ]
# Unique Winning bids: [  30.5   274.5    61.    244.     12.2   128.1   305.    183.    610.
#   442.25  381.25  366.    411.75  176.9   427.    158.6   259.25   91.5
#   320.25  650.    550.    900.    320.   1400.    500.    325.    475.
#  1250.    260.    350.    220.    400.    240.    190.    450.    200.
#   280.     50.    275.    160.    150.    425.     90.    100.     70.
#    30.    600.     60.     65.    180.    130.     55.     80.     75.
#   120.     20.     10.    170.    300.     95.     45.    110.     85.
#    40.    375.   1600.    750.     25.     15.    140.   1050.    380.
#   230.    950.    700.    420.    480.    250.    210.     35.    850.
#  1450.   1200.    520.    760.    540.    940.    640.    560.   1100.
#   620.    360.    960.    740.    780.    800.    440.    580.    340.
# ...

# %%
X = data[['Base price', 'Winning bid']]

# %%
Z = linkage(X, method='ward')

# %%
plt.figure(figsize=(12, 8))
dendrogram(Z)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
plt.show()

# %%
plt.figure(figsize=(8, 6))

plt.scatter(data['Base price'], data.index, color='skyblue', label='Base price')
plt.scatter(data['Winning bid'], data.index, color='lightgreen', label='Winning bid')
plt.title('Scatter Plot of Base price and Winning bid')
plt.xlabel('Price')
plt.ylabel('Index')
plt.legend()

plt.tight_layout()
plt.show()
